# %%
import pandas as pd
import json
import os
import matplotlib.pyplot as plt

# %%
with open('response10.json') as f:
    data = json.load(f)

# %%
# extract the hits array from the JSON data
hits = data['hits']['hits']

# %%
# convert the hits array to a Pandas DataFrame
df = pd.json_normalize(hits)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 68 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   _index                                  10000 non-null  object
#  1   _type                                   10000 non-null  object
#  2   _id                                     10000 non-null  object
#  3   _score                                  10000 non-null  float64
#  4   _source.crawler                         10000 non-null  object
#  5   _source.created                         10000 non-null  object
#  6   _source.created_at_utc                  10000 non-null  object
#  7   _source.favorite_count                  10000 non-null  int64
#  8   _source.hastags                         10000 non-null  object
#  9   _source.in_reply_to_name                1209 non-null   object
# ...

# %%
def read_json_file(df_json):
    with open(df_json) as f:
        data = json.load(f)
    # extract the hits array from the JSON data
    hits = data['hits']['hits']
    # convert the hits array to a Pandas DataFrame
    df = pd.json_normalize(hits)
    return df

# %%
df_okt=read_json_file('response10full.json')

# %%
df_okt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 68 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   _index                                  100000 non-null  object
#  1   _type                                   100000 non-null  object
#  2   _id                                     100000 non-null  object
#  3   _score                                  100000 non-null  float64
#  4   _source.crawler                         100000 non-null  object
#  5   _source.created                         100000 non-null  object
#  6   _source.created_at_utc                  100000 non-null  object
#  7   _source.favorite_count                  100000 non-null  int64
#  8   _source.hastags                         100000 non-null  object
#  9   _source.in_reply_to_name                5058 non-null    object
# ...

# %%
df_okt.to_csv("data_oktober.csv")

# %%
df_nov=read_json_file('response11.json')

# %%
df_des=read_json_file('response12.json')

# %%
df_jan=read_json_file('response01.json')

# %%
df_feb=read_json_file('response02.json')

# %%
df_mar=read_json_file('response03.json')

# %%
df=pd.concat([df_okt,df_nov,df_des,df_jan,df_feb,df_mar],axis=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52295 entries, 0 to 2294
# Data columns (total 68 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   _index                                  52295 non-null  object
#  1   _type                                   52295 non-null  object
#  2   _id                                     52295 non-null  object
#  3   _score                                  52295 non-null  float64
#  4   _source.crawler                         52295 non-null  object
#  5   _source.created                         52295 non-null  object
#  6   _source.created_at_utc                  52295 non-null  object
#  7   _source.favorite_count                  52295 non-null  int64
#  8   _source.hastags                         52295 non-null  object
#  9   _source.in_reply_to_name                5462 non-null   object
# ...

# %%
df
# Out:
#                _index _type                  _id    _score _source.crawler  \
# 0     twitter_2022.10  _doc  1577321224384188416  6.262497         keyword
# 1     twitter_2022.10  _doc  1578336547531001856  6.199590         keyword
# 2     twitter_2022.10  _doc  1582601589772419072  5.962973         keyword
# 3     twitter_2022.10  _doc  1582626937817935872  5.848888         keyword
# 4     twitter_2022.10  _doc  1576309067613876225  5.837208         keyword
# ...               ...   ...                  ...       ...             ...
# 2290  twitter_2023.03  _doc  1633965391545520128  4.964875         keyword
# 2291  twitter_2023.03  _doc  1632914312598802432  4.939639         keyword
# 2292  twitter_2023.03  _doc  1631928038412926976  4.873124         keyword
# 2293  twitter_2023.03  _doc  1632195450542632962  4.857304         keyword
# 2294  twitter_2023.03  _doc  1633415319078293504  4.044835         keyword
#
#                 _source.created     _source.created_at_utc  \
# ...

# %%
df_okt_raw=df_okt[["_id","_source.user.name","_source.message","_source.created","_source.mentions","_source.rt_count","_source.place.name","_source.sentiment","_source.in_reply_to_status","_source.retweeted_status.name","_source.retweeted_status.message","_source.retweeted_status.RT_count","_source.retweeted_status.tweet_id"]]

# %%
df_okt_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   _id                                100000 non-null  object
#  1   _source.user.name                  100000 non-null  object
#  2   _source.message                    100000 non-null  object
#  3   _source.created                    100000 non-null  object
#  4   _source.mentions                   100000 non-null  object
#  5   _source.rt_count                   100000 non-null  int64
#  6   _source.place.name                 566 non-null     object
#  7   _source.sentiment                  100000 non-null  object
#  8   _source.in_reply_to_status         4976 non-null    object
#  9   _source.retweeted_status.name      67447 non-null   object
#  10  _source.retweeted_status.message   67447 non-null   object
# ...

# %%
df_okt_raw.to_csv("dataset_oktober_raw.csv",index=False)

# %%
df_raw=df[["_source.user.name","_source.message","_source.created","_source.mentions","_source.rt_count","_source.place.name","_source.sentiment","_source.retweeted_status.name","_source.retweeted_status.message","_source.retweeted_status.RT_count"]]

# %%
df_raw.to_csv("dataset_6bulan_raw.csv",index=False)

# %%
df_raw
# Out:
#          _source.user.name                                    _source.message  \
# 0     WartaCerdikIndonesia  10 Anggota Polisi Dicopot Buntut Tragedi Kanju...
# 1     WartaCerdikIndonesia  Update Tragedi Kanjuruhan: Sudah 6 Orang Ditet...
# 2            WASIT POLITIK  Masa depan Kanjuruhan\n\nKanjuruhan Kanjuruhan...
# 3                    INODI  RT @antaracilegon: Masa depan Kanjuruhan\n\nKa...
# 4                  SADBOYS                PRAY FOR KANJURUHAN :(\n#kanjuruhan
# ...                    ...                                                ...
# 2290              BFM News  1. Two men have been jailed after an Indonesia...
# 2291    Farid Zainul Hasan  @iwan2701 @ruhutsitompul Lucu aja.. Sok perhat...
# 2292               sya ʚїɞ  @Rizaaa15 @detikcom lo mau protes kaya apa jug...
# 2293                ebiee🦋  @tanyakanrl Kenapa dah di kira GBK punya dia a...
# 2294             vikingblu  @BontotBanten @w4ruga @Zett_Aa @ShalyoWiga @Sa...
#
# ...

# %%
# !pwd
# Out:
# /home/widyawan/2021 Capstone/playground_2023

# %%
data = []
for filename in os.listdir('/home/widyawan/2021 Capstone/playground_2023/'):
    if filename.endswith('.json'):
        with open('/home/widyawan/2021 Capstone/playground_2023/' + filename, 'r') as f:
            json_data = json.load(f)
            hits = json_data['hits']['hits']
            for hit in hits:
                data.append(hit['_source'])

# %%
df = pd.DataFrame(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52295 entries, 0 to 52294
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   coordinate           52295 non-null  object
#  1   crawler              52295 non-null  object
#  2   created              52295 non-null  object
#  3   created_at_utc       52295 non-null  object
#  4   favorite_count       52295 non-null  int64
#  5   geo                  52295 non-null  object
#  6   hastags              52295 non-null  object
#  7   in_reply_to_name     5462 non-null   object
#  8   in_reply_to_status   5418 non-null   object
#  9   in_reply_to_user_id  5462 non-null   object
#  10  language             52295 non-null  object
#  11  lastaccess           52295 non-null  object
#  12  link                 52295 non-null  object
#  13  media_url            52295 non-null  object
#  14  mentions             52295 non-null  object
# ...

# %%
df.head()
# Out:
#   coordinate  crawler                    created             created_at_utc  \
# 0         {}  keyword  2022-12-23T17:29:23+07:00  2022-12-23T10:29:23+00:00
# 1         {}  account  2022-12-30T11:29:21+07:00  2022-12-30T04:29:21+00:00
# 2         {}  account  2022-12-24T13:19:05+07:00  2022-12-24T06:19:05+00:00
# 3         {}  keyword  2022-12-29T21:59:06+07:00  2022-12-29T14:59:06+00:00
# 4         {}  keyword  2022-12-29T20:35:31+07:00  2022-12-29T13:35:31+00:00
#
#    favorite_count geo                                            hastags  \
# 0               0  {}  [TragediKanjuruhan, KanjuruhanDisaster, kanjur...
# 1               0  {}                                                 []
# 2               0  {}                                                 []
# 3               0  {}                                                 []
# 4               0  {}                                                 []
#
# ...

# %%
df.to_csv("dataset_6bulan.csv",index=False)

# %%
df_pol = df[df['message'].str.contains('polisi', case=False)]

# %%
df_pol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3404 entries, 48 to 51681
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   coordinate           3404 non-null   object
#  1   crawler              3404 non-null   object
#  2   created              3404 non-null   object
#  3   created_at_utc       3404 non-null   object
#  4   favorite_count       3404 non-null   int64
#  5   geo                  3404 non-null   object
#  6   hastags              3404 non-null   object
#  7   in_reply_to_name     374 non-null    object
#  8   in_reply_to_status   371 non-null    object
#  9   in_reply_to_user_id  374 non-null    object
#  10  language             3404 non-null   object
#  11  lastaccess           3404 non-null   object
#  12  link                 3404 non-null   object
#  13  media_url            3404 non-null   object
#  14  mentions             3404 non-null   object
# ...

# %%
df_wasit = df[df['message'].str.contains('wasit', case=False)]

# %%
df_wasit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 980 entries, 131 to 51062
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   coordinate           980 non-null    object
#  1   crawler              980 non-null    object
#  2   created              980 non-null    object
#  3   created_at_utc       980 non-null    object
#  4   favorite_count       980 non-null    int64
#  5   geo                  980 non-null    object
#  6   hastags              980 non-null    object
#  7   in_reply_to_name     86 non-null     object
#  8   in_reply_to_status   86 non-null     object
#  9   in_reply_to_user_id  86 non-null     object
#  10  language             980 non-null    object
#  11  lastaccess           980 non-null    object
#  12  link                 980 non-null    object
#  13  media_url            980 non-null    object
#  14  mentions             980 non-null    object
# ...

# %%
df_pssi= df[df['message'].str.contains('pssi', case=False)]

# %%
df_pssi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1567 entries, 25 to 51468
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   coordinate           1567 non-null   object
#  1   crawler              1567 non-null   object
#  2   created              1567 non-null   object
#  3   created_at_utc       1567 non-null   object
#  4   favorite_count       1567 non-null   int64
#  5   geo                  1567 non-null   object
#  6   hastags              1567 non-null   object
#  7   in_reply_to_name     215 non-null    object
#  8   in_reply_to_status   211 non-null    object
#  9   in_reply_to_user_id  215 non-null    object
#  10  language             1567 non-null   object
#  11  lastaccess           1567 non-null   object
#  12  link                 1567 non-null   object
#  13  media_url            1567 non-null   object
#  14  mentions             1567 non-null   object
# ...

# %%
df_arema= df[df['message'].str.contains('arema', case=False)]

# %%
df_arema.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5527 entries, 48 to 51537
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   coordinate           5527 non-null   object
#  1   crawler              5527 non-null   object
#  2   created              5527 non-null   object
#  3   created_at_utc       5527 non-null   object
#  4   favorite_count       5527 non-null   int64
#  5   geo                  5527 non-null   object
#  6   hastags              5527 non-null   object
#  7   in_reply_to_name     216 non-null    object
#  8   in_reply_to_status   210 non-null    object
#  9   in_reply_to_user_id  216 non-null    object
#  10  language             5527 non-null   object
#  11  lastaccess           5527 non-null   object
#  12  link                 5527 non-null   object
#  13  media_url            5527 non-null   object
#  14  mentions             5527 non-null   object
# ...

# %%
def plot_value_counts_pie(df, col_name):
    value_counts = df[col_name].value_counts()
    fig, ax = plt.subplots()
    ax.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=90)
    ax.set_title(f"{col_name.capitalize()} Value Counts")
    plt.show()

# %%
plot_value_counts_pie(df, 'sentiment')

# %%
plot_value_counts_pie(df_pssi, 'sentiment')

# %%
plot_value_counts_pie(df_arema, '_source.sentiment')

# %%
plot_value_counts_pie(df_pol, 'sentiment')

# %%
plot_value_counts_pie(df_wasit, 'sentiment')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_sentiment_pie_chart(df):
    # Count the number of occurrences of each sentiment category
    counts = df['sentiment'].value_counts()

    # Set up the plot using Seaborn
    sns.set(style="whitegrid")
    sns.color_palette("husl")
    fig, ax = plt.subplots(figsize=(6, 4))
    
    # Create the bar plot
    ax = sns.countplot(x='sentiment', data=df, palette="husl")

    # Add labels to the plot
    ax.set_title('Sentiment Distribution')
    ax.set_xlabel('Sentiment')
    ax.set_ylabel('Count')

    # Add percentages to the plot
    total = len(df)
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() / 2 - 0.05
        y = p.get_y() + p.get_height()
        ax.annotate(percentage, (x, y), size=12)

    # Show the plot
    plt.show()

# %%
plot_sentiment_pie_chart(df)

# %%
def plot_sentiment_pie(df):
    sentiment_counts = df['sentiment'].value_counts()
    labels = sentiment_counts.index.tolist()
    sizes = sentiment_counts.values.tolist()

    # Set colors for each sentiment
    colors = ['#ff9999','#66b3ff','#99ff99']

    # Create pie chart
    plt.pie(sizes, colors=colors, labels=labels, autopct='%1.1f%%', startangle=90)
    plt.axis('equal')
    plt.title('Sentiment Distribution')
    plt.show()

# %%
plot_sentiment_pie(df)

# %%
df_neutral=df[df["sentiment"]=="neutral"]
df_neutral.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 25888 to 30412
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   coordinate           7 non-null      object
#  1   crawler              7 non-null      object
#  2   created              7 non-null      object
#  3   created_at_utc       7 non-null      object
#  4   favorite_count       7 non-null      int64
#  5   geo                  7 non-null      object
#  6   hastags              7 non-null      object
#  7   in_reply_to_name     1 non-null      object
#  8   in_reply_to_status   1 non-null      object
#  9   in_reply_to_user_id  1 non-null      object
#  10  language             7 non-null      object
#  11  lastaccess           7 non-null      object
#  12  link                 7 non-null      object
#  13  media_url            7 non-null      object
#  14  mentions             7 non-null      object
# ...

# %%
df['sentiment'] = df['sentiment'].replace('neutral', 'netral')

# %%
plot_sentiment_pie(df_pol)

# %%
plot_sentiment_pie(df_arema)

# %%
plot_sentiment_pie(df_pssi)

# %%
plot_sentiment_pie(df_wasit)

# %%
df
# Out:
#       coordinate  crawler                    created  \
# 0             {}  keyword  2022-12-23T17:29:23+07:00
# 1             {}  account  2022-12-30T11:29:21+07:00
# 2             {}  account  2022-12-24T13:19:05+07:00
# 3             {}  keyword  2022-12-29T21:59:06+07:00
# 4             {}  keyword  2022-12-29T20:35:31+07:00
# ...          ...      ...                        ...
# 52290         {}  keyword  2023-02-12T07:28:48+07:00
# 52291         {}  keyword  2023-02-12T07:30:38+07:00
# 52292         {}  keyword  2023-02-12T07:36:20+07:00
# 52293         {}  keyword  2023-02-12T07:44:20+07:00
# 52294         {}  keyword  2023-02-12T07:45:11+07:00
#
#                   created_at_utc  favorite_count geo  \
# 0      2022-12-23T10:29:23+00:00               0  {}
# 1      2022-12-30T04:29:21+00:00               0  {}
# 2      2022-12-24T06:19:05+00:00               0  {}
# 3      2022-12-29T14:59:06+00:00               0  {}
# 4      2022-12-29T13:35:31+00:00               0  {}
# ...

# %%
data = []
for filename in os.listdir('/home/widyawan/2021 Capstone/playground_2023/'):
    if filename.endswith('.json'):
        with open('/home/widyawan/2021 Capstone/playground_2023/' + filename, 'r') as f:
            json_data = json.load(f)
            hits = json_data['hits']['hits']
            data.append(hits)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                                 0     \
# 0  {'_index': 'twitter_2022.12', '_type': '_doc',...
# 1  {'_index': 'twitter_2022.11', '_type': '_doc',...
# 2  {'_index': 'twitter_2022.10', '_type': '_doc',...
# 3  {'_index': 'twitter_2023.01', '_type': '_doc',...
# 4  {'_index': 'twitter_2023.03', '_type': '_doc',...
# 5  {'_index': 'twitter_2023.02', '_type': '_doc',...
#
#                                                 1     \
# 0  {'_index': 'twitter_2022.12', '_type': '_doc',...
# 1  {'_index': 'twitter_2022.11', '_type': '_doc',...
# 2  {'_index': 'twitter_2022.10', '_type': '_doc',...
# 3  {'_index': 'twitter_2023.01', '_type': '_doc',...
# 4  {'_index': 'twitter_2023.03', '_type': '_doc',...
# 5  {'_index': 'twitter_2023.02', '_type': '_doc',...
#
#                                                 2     \
# 0  {'_index': 'twitter_2022.12', '_type': '_doc',...
# 1  {'_index': 'twitter_2022.11', '_type': '_doc',...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Columns: 10000 entries, 0 to 9999
# dtypes: object(10000)
# memory usage: 468.9+ KB

# %%
df_raw
# Out:
#          _source.user.name                                    _source.message  \
# 0     WartaCerdikIndonesia  10 Anggota Polisi Dicopot Buntut Tragedi Kanju...
# 1     WartaCerdikIndonesia  Update Tragedi Kanjuruhan: Sudah 6 Orang Ditet...
# 2            WASIT POLITIK  Masa depan Kanjuruhan\n\nKanjuruhan Kanjuruhan...
# 3                    INODI  RT @antaracilegon: Masa depan Kanjuruhan\n\nKa...
# 4                  SADBOYS                PRAY FOR KANJURUHAN :(\n#kanjuruhan
# ...                    ...                                                ...
# 2290              BFM News  1. Two men have been jailed after an Indonesia...
# 2291    Farid Zainul Hasan  @iwan2701 @ruhutsitompul Lucu aja.. Sok perhat...
# 2292               sya ʚїɞ  @Rizaaa15 @detikcom lo mau protes kaya apa jug...
# 2293                ebiee🦋  @tanyakanrl Kenapa dah di kira GBK punya dia a...
# 2294             vikingblu  @BontotBanten @w4ruga @Zett_Aa @ShalyoWiga @Sa...
#
# ...

# %%
sorted_df = df_raw.sort_values(by=['_source.rt_count'], ascending=False)

# %%
sorted_df
# Out:
#               _source.user.name  \
# 7184                 Galih Okky
# 7191                        Ann
# 9521                         jo
# 7185  amaze | masih fase sedih🙏
# 7183                      kinoy
# ...                         ...
# 7440               kk #aporla15
# 7441                      Kembu
# 7442         Indri Puji Lestari
# 7443                       Suka
# 2294                  vikingblu
#
#                                         _source.message  \
# 7184  RT @ngabdul: Ibu Mega belum mendatangi Kanjuru...
# 7191  RT @ngabdul: Ibu Mega belum mendatangi Kanjuru...
# 9521  RT @ngabdul: Ibu Mega belum mendatangi Kanjuru...
# 7185  RT @ngabdul: Ibu Mega belum mendatangi Kanjuru...
# 7183  RT @ngabdul: Ibu Mega belum mendatangi Kanjuru...
# ...                                                 ...
# 7440  RT @ngabdul: Ibu Mega belum mendatangi Kanjuru...
# 7441  RT @crazylionzine: HASIL UJI LAB: GAS AIR MATA...
# 7442  RT @ngabdul: Ibu Mega belum mendatangi Kanjuru...
# ...

# %%
sorted_df.drop_duplicates(subset="_source.message")
# Out:
#            _source.user.name  \
# 7184              Galih Okky
# 6214                   eR_eN
# 9762    MinumMakananBergizi🎶
# 430                   Masako
# 512                 Jamily m
# ...                      ...
# 7491                Na nafia
# 7403    AHSAN FURQAN IBRAHIM
# 7386           ig: ohmasgoff
# 7467  pirja. valery legasov.
# 2294               vikingblu
#
#                                         _source.message  \
# 7184  RT @ngabdul: Ibu Mega belum mendatangi Kanjuru...
# 6214  RT @theIawless: Kalau kamu ingin melihat bobro...
# 9762  RT @MafiaWasit: Dari Tragedi Kanjuruhan kita b...
# 430   RT @CNNIndonesia: Polisi Divonis Bebas karena ...
# 512   RT @CNNIndonesia: 135 Orang Tewas, Gas Air Mat...
# ...                                                 ...
# 7491  @puanmaharani_ri kanjuruhan di ank tirikn,fiks...
# 7403  Cc mbak @puanmaharani_ri dan ibu Ketum @PDI_Pe...
# 7386  ralucu rasah kakean pecingisian kemethak kanju...
# ...

# %%
df_okt_raw
# Out:
#                        _id     _source.user.name  \
# 0      1577321224384188416  WartaCerdikIndonesia
# 1      1578336547531001856  WartaCerdikIndonesia
# 2      1582601589772419072         WASIT POLITIK
# 3      1582626937817935872                 INODI
# 4      1576309067613876225               SADBOYS
# ...                    ...                   ...
# 99995  1576718690736693250            Satriawign
# 99996  1576718880466010112              M. Syalu
# 99997  1576719155151089665           Anak Sultan
# 99998  1576719908913938433                  zah🐧
# 99999  1576720176607035393                Irving
#
#                                          _source.message  \
# 0      10 Anggota Polisi Dicopot Buntut Tragedi Kanju...
# 1      Update Tragedi Kanjuruhan: Sudah 6 Orang Ditet...
# 2      Masa depan Kanjuruhan\n\nKanjuruhan Kanjuruhan...
# 3      RT @antaracilegon: Masa depan Kanjuruhan\n\nKa...
# 4                    PRAY FOR KANJURUHAN :(\n#kanjuruhan
# ...

# %%
df_clean=df_okt_raw[df_okt_raw["_source.sentiment"]=="neutral"]
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 5888 to 67297
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   _id                                15 non-null     object
#  1   _source.user.name                  15 non-null     object
#  2   _source.message                    15 non-null     object
#  3   _source.created                    15 non-null     object
#  4   _source.mentions                   15 non-null     object
#  5   _source.rt_count                   15 non-null     int64
#  6   _source.place.name                 0 non-null      object
#  7   _source.sentiment                  15 non-null     object
#  8   _source.in_reply_to_status         4 non-null      object
#  9   _source.retweeted_status.name      5 non-null      object
#  10  _source.retweeted_status.message   5 non-null      object
# ...

# %%
df_okt_raw['_source.sentiment'] = df_okt_raw['_source.sentiment'].replace('neutral', 'netral')
# Out:
# /home/widyawan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_okt_raw
# Out:
#                        _id     _source.user.name  \
# 0      1577321224384188416  WartaCerdikIndonesia
# 1      1578336547531001856  WartaCerdikIndonesia
# 2      1582601589772419072         WASIT POLITIK
# 3      1582626937817935872                 INODI
# 4      1576309067613876225               SADBOYS
# ...                    ...                   ...
# 99995  1576718690736693250            Satriawign
# 99996  1576718880466010112              M. Syalu
# 99997  1576719155151089665           Anak Sultan
# 99998  1576719908913938433                  zah🐧
# 99999  1576720176607035393                Irving
#
#                                          _source.message  \
# 0      10 Anggota Polisi Dicopot Buntut Tragedi Kanju...
# 1      Update Tragedi Kanjuruhan: Sudah 6 Orang Ditet...
# 2      Masa depan Kanjuruhan\n\nKanjuruhan Kanjuruhan...
# 3      RT @antaracilegon: Masa depan Kanjuruhan\n\nKa...
# 4                    PRAY FOR KANJURUHAN :(\n#kanjuruhan
# ...

# %%
df_arema= df_okt_raw[df_okt_raw['_source.message'].str.contains('arema', case=False)]
df_arema.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12314 entries, 8 to 99894
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   _id                                12314 non-null  object
#  1   _source.user.name                  12314 non-null  object
#  2   _source.message                    12314 non-null  object
#  3   _source.created                    12314 non-null  object
#  4   _source.mentions                   12314 non-null  object
#  5   _source.rt_count                   12314 non-null  int64
#  6   _source.place.name                 73 non-null     object
#  7   _source.sentiment                  12314 non-null  object
#  8   _source.in_reply_to_status         402 non-null    object
#  9   _source.retweeted_status.name      9055 non-null   object
#  10  _source.retweeted_status.message   9055 non-null   object
# ...

# %%
df_psby= df_okt_raw[df_okt_raw['_source.message'].str.contains('persebaya', case=False)]
df_psby.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1688 entries, 50 to 99850
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   _id                                1688 non-null   object
#  1   _source.user.name                  1688 non-null   object
#  2   _source.message                    1688 non-null   object
#  3   _source.created                    1688 non-null   object
#  4   _source.mentions                   1688 non-null   object
#  5   _source.rt_count                   1688 non-null   int64
#  6   _source.place.name                 20 non-null     object
#  7   _source.sentiment                  1688 non-null   object
#  8   _source.in_reply_to_status         124 non-null    object
#  9   _source.retweeted_status.name      715 non-null    object
#  10  _source.retweeted_status.message   715 non-null    object
# ...

# %%
df_persija= df_okt_raw[df_okt_raw['_source.message'].str.contains('persija', case=False)]
df_persija.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 165 entries, 152 to 99989
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   _id                                165 non-null    object
#  1   _source.user.name                  165 non-null    object
#  2   _source.message                    165 non-null    object
#  3   _source.created                    165 non-null    object
#  4   _source.mentions                   165 non-null    object
#  5   _source.rt_count                   165 non-null    int64
#  6   _source.place.name                 1 non-null      object
#  7   _source.sentiment                  165 non-null    object
#  8   _source.in_reply_to_status         16 non-null     object
#  9   _source.retweeted_status.name      21 non-null     object
#  10  _source.retweeted_status.message   21 non-null     object
# ...

# %%
df_persib= df_okt_raw[df_okt_raw['_source.message'].str.contains('persib', case=False)]
df_persib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 2135 to 99989
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   _id                                200 non-null    object
#  1   _source.user.name                  200 non-null    object
#  2   _source.message                    200 non-null    object
#  3   _source.created                    200 non-null    object
#  4   _source.mentions                   200 non-null    object
#  5   _source.rt_count                   200 non-null    int64
#  6   _source.place.name                 0 non-null      object
#  7   _source.sentiment                  200 non-null    object
#  8   _source.in_reply_to_status         24 non-null     object
#  9   _source.retweeted_status.name      22 non-null     object
#  10  _source.retweeted_status.message   22 non-null     object
# ...

# %%
df_persis= df_okt_raw[df_okt_raw['_source.message'].str.contains('persis', case=False)]
df_persis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 154 to 95200
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   _id                                42 non-null     object
#  1   _source.user.name                  42 non-null     object
#  2   _source.message                    42 non-null     object
#  3   _source.created                    42 non-null     object
#  4   _source.mentions                   42 non-null     object
#  5   _source.rt_count                   42 non-null     int64
#  6   _source.place.name                 1 non-null      object
#  7   _source.sentiment                  42 non-null     object
#  8   _source.in_reply_to_status         9 non-null      object
#  9   _source.retweeted_status.name      8 non-null      object
#  10  _source.retweeted_status.message   8 non-null      object
# ...

# %%
df_psm= df_okt_raw[df_okt_raw['_source.message'].str.contains('psm', case=False)]
df_psm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 5810 to 98660
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   _id                                50 non-null     object
#  1   _source.user.name                  50 non-null     object
#  2   _source.message                    50 non-null     object
#  3   _source.created                    50 non-null     object
#  4   _source.mentions                   50 non-null     object
#  5   _source.rt_count                   50 non-null     int64
#  6   _source.place.name                 0 non-null      object
#  7   _source.sentiment                  50 non-null     object
#  8   _source.in_reply_to_status         0 non-null      object
#  9   _source.retweeted_status.name      11 non-null     object
#  10  _source.retweeted_status.message   11 non-null     object
# ...

# %%
df_Bu= df_okt_raw[df_okt_raw['_source.message'].str.contains('Barito Putera', case=False)]
df_Bu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 77359 to 77359
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   _id                                1 non-null      object
#  1   _source.user.name                  1 non-null      object
#  2   _source.message                    1 non-null      object
#  3   _source.created                    1 non-null      object
#  4   _source.mentions                   1 non-null      object
#  5   _source.rt_count                   1 non-null      int64
#  6   _source.place.name                 0 non-null      object
#  7   _source.sentiment                  1 non-null      object
#  8   _source.in_reply_to_status         0 non-null      object
#  9   _source.retweeted_status.name      0 non-null      object
#  10  _source.retweeted_status.message   0 non-null      object
# ...

# %%
# def plot_sentiment_pie(df):
#     sentiment_counts = df['_source.sentiment'].value_counts()
#     sizes = sentiment_counts.values.tolist()
#     labels = sentiment_counts.index.tolist()

#     # Set colors and labels for each sentiment
#     colors = ['#ff9999','#66b3ff','#99ff99']
#     labels = ['Negative', 'Neutral', 'Positive']

#     # Create pie chart
#     plt.pie(sizes, colors=colors, startangle=90)

#     # Add legend
#     plt.legend(labels=labels)

#     plt.axis('equal')
#     plt.title('Sentiment Distribution')
#     plt.show()

# %%
def plot_sentiment_pie(df):
    sentiment_counts = df['_source.sentiment'].value_counts()
#     labels = sentiment_counts.index.tolist()
    sizes = sentiment_counts.values.tolist()

    # Set colors for each sentiment
    colors = ['#ff9999','#66b3ff','#99ff99']

    # Create pie chart
    plt.pie(sizes, colors=colors, startangle=90)
    plt.axis('equal')
    plt.title('Sentiment Distribution')
    plt.show()
    print("Sentiment Percentage:")
    for sentiment, count in sentiment_counts.items():
        percentage = count / len(df) * 100
        print(f"{sentiment}: {percentage:.2f}%")
    print(f"Total rows: {len(df)}")

# %%
def plot_sentiment_percentage(df):
    sentiment_counts = df['_source.sentiment'].value_counts(normalize=True) * 100
    sentiment_counts.plot(kind='barh', color=['#ff9999', '#66b3ff', '#99ff99'])
    plt.xlabel('Percentage')
    plt.title('Sentiment Percentage')
    plt.show()

# %%
sentiment_counts = df_arema['_source.sentiment'].value_counts(normalize=True) * 100

# %%
sentiment_counts
# Out:
# netral     95.245167
# negatif     4.424965
# positif     0.314098
# neutral     0.015771
# Name: _source.sentiment, dtype: float64

# %%
plot_sentiment_percentage(df_arema)

# %%
cream=netral
biru=negatif
hijau=positif

# %%
plot_sentiment_pie(df_arema)

# %%
plot_sentiment_pie(read_json_file('response10persebaya.json'))

# %%
def visualize_pie(df):
    df_sup=read_json_file(df)
    df_clean=df_sup[["_id","_source.user.name","_source.message","_source.created","_source.mentions","_source.rt_count","_source.sentiment","_source.in_reply_to_status","_source.retweeted_status.name","_source.retweeted_status.message","_source.retweeted_status.RT_count","_source.retweeted_status.tweet_id"]]
    df_clean['_source.sentiment'] = df_clean['_source.sentiment'].replace('neutral', 'netral')
    plot_sentiment_pie(df_clean)
    plot_sentiment_percentage(df_clean)

# %%
visualize_pie('response10persebaya.json')
# Out:
# /home/widyawan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# Sentiment Percentage:
# netral: 95.77%
# negatif: 2.87%
# positif: 1.36%
# Total rows: 33027

# %%
visualize_pie('response10arema.json')
# Out:
# /home/widyawan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# Sentiment Percentage:
# netral: 95.26%
# negatif: 4.42%
# positif: 0.31%
# Total rows: 76091

# %%
visualize_pie('response10persija.json')
# Out:
# /home/widyawan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# Sentiment Percentage:
# netral: 98.22%
# negatif: 1.36%
# positif: 0.42%
# Total rows: 4499

# %%
visualize_pie('response10bali.json')
# Out:
# /home/widyawan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# Sentiment Percentage:
# netral: 50.27%
# negatif: 47.73%
# positif: 2.00%
# Total rows: 1102

# %%
visualize_pie('response10persija.json')
# Out:
# /home/widyawan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# Sentiment Percentage:
# netral: 98.22%
# negatif: 1.36%
# positif: 0.42%
# Total rows: 4499

# %%
visualize_pie('response10persib.json')
# Out:
# /home/widyawan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# Sentiment Percentage:
# netral: 95.47%
# negatif: 3.17%
# positif: 1.36%
# Total rows: 3091

# %%
visualize_pie('response10persis.json')
# Out:
# /home/widyawan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# Sentiment Percentage:
# netral: 96.86%
# negatif: 2.87%
# positif: 0.27%
# Total rows: 2228

# %%
visualize_pie('response10psis.json')
# Out:
# /home/widyawan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# Sentiment Percentage:
# netral: 97.81%
# negatif: 1.64%
# positif: 0.55%
# Total rows: 365

# %%
visualize_pie('response10psm.json')
# Out:
# /home/widyawan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# Sentiment Percentage:
# netral: 99.01%
# positif: 0.59%
# negatif: 0.40%
# Total rows: 506

# %%
visualize_pie('response10pss.json')
# Out:
# /home/widyawan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# Sentiment Percentage:
# netral: 99.07%
# positif: 0.50%
# negatif: 0.43%
# Total rows: 1610

# %%
visualize_pie('response10madura.json')
# Out:
# /home/widyawan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# Sentiment Percentage:
# netral: 94.16%
# negatif: 5.73%
# positif: 0.11%
# Total rows: 8948

# %%
visualize_pie('response10barito.json')
# Out:
# /home/widyawan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# Sentiment Percentage:
# netral: 88.89%
# negatif: 11.11%
# Total rows: 18

# %%
visualize_pie(df_okt_raw)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-178-6b4b72f39b68> in <module>
# ----> 1 visualize_pie(df_okt_raw)
#
# <ipython-input-177-75766848c1c5> in visualize_pie(df)
#       1 def visualize_pie(df):
# ----> 2     df_sup=read_json_file(df)
#       3     df_clean=df_sup[["_id","_source.user.name","_source.message","_source.created","_source.mentions","_source.rt_count","_source.sentiment","_source.in_reply_to_status","_source.retweeted_status.name","_source.retweeted_status.message","_source.retweeted_status.RT_count","_source.retweeted_status.tweet_id"]]
#       4     df_clean['_source.sentiment'] = df_clean['_source.sentiment'].replace('neutral', 'netral')
#       5     plot_sentiment_pie(df_clean)
#
# <ipython-input-87-e7a09b0cf886> in read_json_file(df_json)
#       1 def read_json_file(df_json):
# ----> 2     with open(df_json) as f:
# ...

# %%
plot_sentiment_pie(df_okt_raw)
# Out:
# Sentiment Percentage:
# netral: 89.57%
# negatif: 8.18%
# positif: 2.25%
# Total rows: 100000

# %%
df_okt_raw
# Out:
#                        _id     _source.user.name  \
# 0      1577321224384188416  WartaCerdikIndonesia
# 1      1578336547531001856  WartaCerdikIndonesia
# 2      1582601589772419072         WASIT POLITIK
# 3      1582626937817935872                 INODI
# 4      1576309067613876225               SADBOYS
# ...                    ...                   ...
# 99995  1576718690736693250            Satriawign
# 99996  1576718880466010112              M. Syalu
# 99997  1576719155151089665           Anak Sultan
# 99998  1576719908913938433                  zah🐧
# 99999  1576720176607035393                Irving
#
#                                          _source.message  \
# 0      10 Anggota Polisi Dicopot Buntut Tragedi Kanju...
# 1      Update Tragedi Kanjuruhan: Sudah 6 Orang Ditet...
# 2      Masa depan Kanjuruhan\n\nKanjuruhan Kanjuruhan...
# 3      RT @antaracilegon: Masa depan Kanjuruhan\n\nKa...
# 4                    PRAY FOR KANJURUHAN :(\n#kanjuruhan
# ...

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

import matplotlib.dates as mdates

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize, TweetTokenizer
from nltk.corpus import stopwords

from collections import Counter
from tqdm import tqdm
import os
import random
import re
import string
import pickle
import json
from io import StringIO
# Out:
# [nltk_data] Downloading package punkt to /home/widyawan/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/widyawan/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 1.5 MB 2.2 MB/s
# ...

# %%
alay_dict = pd.read_csv('https://raw.githubusercontent.com/okkyibrohim/id-multi-label-hate-speech-and-abusive-language-detection/master/new_kamusalay.csv', encoding='latin-1', header=None)
alay_dict = alay_dict.rename(columns={0: 'original', 
                                      1: 'replacement'})

idn_stopwords = stopwords.words('indonesian')

# %%
idn_stopwords.append(["ada","di","RT"])

# %%
tweet_tokenizer = TweetTokenizer()

def tokenize_tweet(text):
    return " ".join(tweet_tokenizer.tokenize(text))


def preprocess_tweet(text):
  text = re.sub('\n',' ',text) # Remove every '\n'
  text = re.sub('\n',' ',text) # Remove every '\n'
  # text = re.sub('rt',' ',text) # Remove every retweet symbol
  text = re.sub('^(\@\w+ ?)+',' ',text)
  text = re.sub(r'\@\w+',' ',text) # Remove every username
  text = re.sub('((www\.[^\s]+)|(https?://[^\s]+)|(http?://[^\s]+))',' ',text) # Remove every URL
  text = re.sub('/', ' ', text)
  text = re.sub("\d+", "", text) #Remove Numbers
  # text = re.sub(r'[^\w\s]', '', text)
  text = re.sub('  +', ' ', text) # Remove extra spaces
  return text

alay_dict_map = dict(zip(alay_dict['original'], alay_dict['replacement']))
alay_dict_map.update({
    "pks"   : "pencegahan kekerasan seksual",
    "p-ks"  : "pencegahan kekerasan seksual",
    "ks"    : "kekerasan seksual"
})
def normalize_alay(text):
  return ' '.join([alay_dict_map[word] if word in alay_dict_map else word for word in text.split(' ')])
    
def remove_nonaplhanumeric(text):
  text = re.sub('[^0-9a-zA-Z]+', ' ', text) 
  return text

def remove_stopword(text):
  text = ' '.join(['' if word in idn_stopwords else word for word in text.split(' ')])
  text = re.sub('  +', ' ', text)
  text = text.strip()
  return text

def multiple_word_remove_func(text, words_2_remove_list):     
    words_to_remove_list = words_2_remove_list
    
    words = word_tokenize(text)
    text = ' '.join([word for word in words if word not in words_to_remove_list])
    return text

print("remove_nonaplhanumeric: ", remove_nonaplhanumeric("Halooo,,,,, duniaa!!"))
print("lowercase: ", ("Halooo, duniaa!".lower()))
print("normalize_alay: ", normalize_alay("@Jokowi jokowi aamiin adek abis"))
# Out:
# remove_nonaplhanumeric:  Halooo duniaa
# lowercase:  halooo, duniaa!
# normalize_alay:  @Jokowi jokowi amin adik habis

# %%
def preprocess(text, alay = False, tweet = False):
  # text = remove_unnecessary_char(text)
  text = text.lower()
  if (tweet):
    text = preprocess_tweet(text)
  
  # text = tokenize_tweet(text)
  
  if (alay):
    text = normalize_alay(text)
  return text

# %%
df_okt_raw["clean_text"] = df_okt_raw["_source.message"].apply(preprocess, args = (True, True,))
df_okt_raw["no_stopword_text"] = df_okt_raw["clean_text"].apply(remove_nonaplhanumeric).apply(remove_stopword)
df_okt_raw["Tweet"] = df_okt_raw.apply(lambda x: multiple_word_remove_func(x["no_stopword_text"], 
                                                         ["hai","haha","kartu","tarot","kinal","kayak","orang","iya","tau","wkwk","gue","nya","sih","nih","banget","zodiak","ramalan","ya","desember","januari","aries", "taurus", "gemini","cancer","leo","virgo","libra","scorpio","sagitarius","capricorn","aquarius","pisces"]), axis = 1)

df_okt_raw[["_source.message", "clean_text", "no_stopword_text","Tweet"]]
# Out:
# /home/widyawan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/widyawan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/widyawan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
kata_judul= list(df_okt_raw["_source.message"].apply(lambda x: x.split()))
kata_judul = [x for y in kata_judul for x in y]
Counter(kata_judul).most_common(50)
# Out:
# [('RT', 67684),
#  ('Kanjuruhan', 58353),
#  ('Tragedi', 45750),
#  ('@CNNIndonesia:', 32156),
#  ('di', 23093),
#  ('Kanjuruhan,', 16042),
#  ('untuk', 10546),
#  ('Korban', 10343),
#  ('Stadion', 9680),
#  ('tragedi', 8973),
#  ('Polisi', 8703),
#  ('yang', 7880),
#  ('kanjuruhan', 7669),
#  ('Indonesia', 7126),
#  ('#kanjuruhan', 6778),
#  ('korban', 6497),
#  ('Kapolri', 6275),
#  ('ARMY', 5793),
#  ('Juta', 5771),
#  ('Galang', 5740),
#  ('Dana', 5714),
#  ('dan', 5691),
#  ('Polri', 5495),
#  ('Malang', 5351),
#  ('Orang', 4633),
#  ('Tembus', 4632),
#  ('Rp420', 4625),
#  ('https://t.co/39aLMB8Q1G', 4622),
#  ('Mata', 4555),
#  ('Gas', 4521),
#  ('Air', 4457),
#  ('PSSI', 4349),
#  ('Kanjuruhan:', 4309),
#  ('dari', 4264),
#  ('atas', 3939),
#  ('FIFA', 3910),
#  ('@VIVAcoid:', 3888),
#  ('Turut', 3681),
#  ('Aremania', 3673),
#  ('Kanjuruhan.', 3586),
#  ('Buntut', 3549),
#  ('berduka', 3453),
#  ('Kapolres', 3352),
#  ('dalam', 3208),
#  ('Ada', 3116),
# ...

# %%
merged_text = " ".join(df_okt_raw["_source.message"])

# %%
wordcloud = WordCloud(width = 1600, height = 800, max_font_size=128, max_words=1000,scale=4, background_color="white").generate(" ".join(kata_judul))

# %%
def grey_color_func(word, font_size, position, orientation, random_state=None,
                    **kwargs):
    return "hsl(0, 0%%, %d%%)" % random.randint(60, 100)
plt.figure(figsize=(15,10))
my_dpi=960
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
